# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\lenovo\Downloads\8. Netflix Dataset.csv")

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7777   s7783    Movie                                     Zozo
# 7778   s7784    Movie                                   Zubaan
# 7779   s7785    Movie                        Zulu Man in Japan
# 7780   s7786  TV Show                    Zumbo's Just Desserts
# 7781   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # Basic information

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4    01-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7777   s7783    Movie                                     Zozo  Josef Fares
# 7778   s7784    Movie                                   Zubaan  Mozez Singh
# 7779   s7785    Movie                        Zulu Man in Japan          NaN
# 7780   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7781   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7777  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7778  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7779                                            Nasty C
# 7780                         Adriano Zumbo, Rachel Khoo
# 7781                                                NaN
#
#                                                 Country Release_Date Rating  \
# 7777  Sweden, Czech Republic, United Kingdom, Denmar...    19-Oct-20  TV-MA
# ...

# %%
data.shape
# Out:
# (7782, 11)

# %%
data.size
# Out:
# 85602

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7782 entries, 0 to 7781
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7782 non-null   object
#  1   Category      7782 non-null   object
#  2   Title         7782 non-null   object
#  3   Director      5397 non-null   object
#  4   Cast          7065 non-null   object
#  5   Country       7276 non-null   object
#  6   Release_Date  7772 non-null   object
#  7   Rating        7775 non-null   object
#  8   Duration      7782 non-null   object
#  9   Type          7782 non-null   object
#  10  Description   7782 non-null   object
# dtypes: object(11)
# memory usage: 668.9+ KB

# %% [markdown]
# # Task1. Is there any duplicate record in this dataset? If yes, then remove the duplicate record.

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.shape
# Out:
# (7782, 11)

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6293    s684    Movie           Backfire     Dave Patten
# 6615   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6293  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6615  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#      Release_Date Rating Duration                                   Type  \
# 6293    05-Apr-19  TV-MA   97 min  Dramas, Independent Movies, Thrillers
# 6615    04-Sep-20  TV-MA   94 min   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6293  When two would-be robbers accidentally kill a ...
# 6615  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace = True)

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7777   s7783    Movie                                     Zozo
# 7778   s7784    Movie                                   Zubaan
# 7779   s7785    Movie                        Zulu Man in Japan
# 7780   s7786  TV Show                    Zumbo's Just Desserts
# 7781   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # Task 2. Is there any null value present in any column? show with heat-map

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4    01-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2385
# Cast             717
# Country          506
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ## Heat-map

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # ques1 For 'House of cards' , what is the show id & who is the director of this show

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data[data['Title'].str.contains('House of cards')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# # Ques 2. in which year highest number of tv shows & movies were released ? Show this in bar graph

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'])

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7777   s7783    Movie                                     Zozo
# 7778   s7784    Movie                                   Zubaan
# 7779   s7785    Movie                        Zulu Man in Japan
# 7780   s7786  TV Show                    Zumbo's Just Desserts
# 7781   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2150
# 2020.0    2008
# 2018.0    1684
# 2017.0    1223
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Ques 3 How many movies & Tv shows are in the data set show with bar graph

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5372
# TV Show    2408
# Name: Category, dtype: int64

# %%
sns.countplot(data['Category'])
# Out:
# C:\Users\lenovo\anaconda3\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# # ques 4 How Can We Sort data set by year?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4    01-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data['Year'] = data['Date_N'].dt.year

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7777   s7783    Movie                                     Zozo
# 7778   s7784    Movie                                   Zubaan
# 7779   s7785    Movie                        Zulu Man in Japan
# 7780   s7786  TV Show                    Zumbo's Just Desserts
# 7781   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.sort_values(by='Year', ascending= False)
# Out:
#      Show_Id Category                                              Title  \
# 6241   s6248    Movie                                 The Creative Brain
# 3434   s3442  TV Show                         Korean Pork Belly Rhapsody
# 5973   s5980    Movie                                        Tanda Tanya
# 553     s561    Movie                                           Apaharan
# 1348   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# ...      ...      ...                                                ...
# 3367   s3375  TV Show                                           Kikoriki
# 3485   s3493  TV Show                                La Familia P. Luche
# 3939   s3947  TV Show                                              Maron
# 5131   s5138  TV Show                                       Red vs. Blue
# 6059   s6066  TV Show                       The Adventures of Figaro Pho
#
#                              Director  \
# 6241  Jennifer Beamish, Toby Trackman
# ...

# %% [markdown]
# # Ques 5 show only the titles of all tv shows that were released in India only

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'India')]['Title']
# Out:
# 9                                   Feb-09
# 79            21 Sarfarosh: Saragarhi 1897
# 125                              7 (Seven)
# 333                           Agent Raghav
# 357                           Akbar Birbal
#                        ...
# 6242                  The Creative Indians
# 6393    The Golden Years with Javed Akhtar
# 6462                The House That Made Me
# 7287                            Typewriter
# 7698                       Yeh Meri Family
# Name: Title, Length: 72, dtype: object

# %% [markdown]
# # Ques 6 Show top 10 directors , who gave the highest number of TV shows & movies to netflix

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# ...

# %%
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Kunle Afolayan             8
# Name: Director, dtype: int64

# %% [markdown]
# # ques 7 What are the different rating defined by netflix?

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # ques8 How many tv shows got the 'R' rating , after year 2018 ?

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[(data['Category'] == 'TV Show') & (data['Rating'] =='R') & (data['Year']>2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6430   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6430  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN    25-Apr-19
#
#      Rating  Duration      Type  \
# 6430      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6430  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# # ques9 How many type of duration of a movie\ show on netflix?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4    01-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '149 min', '144 min', '124 min', '87 min',
#        '110 min', '128 min', '117 min', '100 min', '2 Seasons', '84 min',
#        '99 min', '90 min', '102 min', '104 min', '105 min', '56 min',
#        '125 min', '81 min', '97 min', '106 min', '107 min', '89 min',
#        '109 min', '44 min', '75 min', '101 min', '3 Seasons', '37 min',
#        '113 min', '114 min', '130 min', '94 min', '143 min', '91 min',
#        '140 min', '135 min', '82 min', '70 min', '121 min', '92 min',
#        '164 min', '53 min', '83 min', '116 min', '86 min', '120 min',
#        '96 min', '126 min', '129 min', '103 min', '77 min', '137 min',
#        '148 min', '28 min', '122 min', '176 min', '85 min', '22 min',
#        '68 min', '111 min', '29 min', '142 min', '168 min', '21 min',
#        '59 min', '20 min', '98 min', '108 min', '76 min', '26 min',
# ...

# %%
data['Duration'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# # ques10 Which  country has the highest number of tv shows?

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   (Minutes, Units)
# 0        4 Seasons
# 1           93 min

# %%
data_tvshow = data[data['Category'] == 'TV Show']

# %%
data_tvshow
# Out:
#      Show_Id Category                                Title      Director  \
# 0         s1  TV Show                                   3%           NaN
# 5         s6  TV Show                                   46   Serdar Akar
# 9        s17  TV Show                               Feb-09  Vikram Bhatt
# 17       s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac           NaN
# 19       s27  TV Show                             (Un)Well           NaN
# ...      ...      ...                                  ...           ...
# 7762   s7768  TV Show                   Zindagi Gulzar Hai           NaN
# 7770   s7776  TV Show                           Zoids Wild           NaN
# 7772   s7778  TV Show                          Zombie Dumb           NaN
# 7774   s7780  TV Show                            Zona Rosa           NaN
# 7780   s7786  TV Show                Zumbo's Just Desserts           NaN
#
#                                                    Cast        Country  \
# ...

# %%
 data_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64
